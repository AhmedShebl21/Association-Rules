# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
data = pd.read_excel("data_q1.xlsx")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    T1  A  B Unnamed: 3 Unnamed: 4
# 0  T2  B  D        NaN        NaN
# 1  T3  B  C        NaN        NaN
# 2  T4  A  B          D        NaN
# 3  T5  A  C        NaN        NaN
# 4  T6  B  C        NaN        NaN
# 5  T7  A  C        NaN        NaN
# 6  T8  A  B          C          E
# 7  T9  A  B          C        NaN

# %%
q1 = pd.read_excel('data_q1.xlsx', header=None)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
q1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     0  1  2    3    4
# 0  T1  A  B  NaN  NaN
# 1  T2  B  D  NaN  NaN
# 2  T3  B  C  NaN  NaN
# 3  T4  A  B    D  NaN
# 4  T5  A  C  NaN  NaN
# 5  T6  B  C  NaN  NaN
# 6  T7  A  C  NaN  NaN
# 7  T8  A  B    C    E
# 8  T9  A  B    C  NaN

# %%
q1.drop(0,axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
q1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    1  2    3    4
# 0  A  B  NaN  NaN
# 1  B  D  NaN  NaN
# 2  B  C  NaN  NaN
# 3  A  B    D  NaN
# 4  A  C  NaN  NaN
# 5  B  C  NaN  NaN
# 6  A  C  NaN  NaN
# 7  A  B    C    E
# 8  A  B    C  NaN

# %%
records = []
for i in range(0, 9):
    records.append([str(q1.values[i,j]) for j in range(0, 4)])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
records
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['A', 'B', 'nan', 'nan'],
#  ['B', 'D', 'nan', 'nan'],
#  ['B', 'C', 'nan', 'nan'],
#  ['A', 'B', 'D', 'nan'],
#  ['A', 'C', 'nan', 'nan'],
#  ['B', 'C', 'nan', 'nan'],
#  ['A', 'C', 'nan', 'nan'],
#  ['A', 'B', 'C', 'E'],
#  ['A', 'B', 'C', 'nan']]

# %%
te = TransactionEncoder()
te_ary=te.fit(records).transform(records)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df=pd.DataFrame(te_ary,columns=te.columns_)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        A      B      C      D      E    nan
# 0   True   True  False  False  False   True
# 1  False   True  False   True  False   True
# 2  False   True   True  False  False   True
# 3   True   True  False   True  False   True
# 4   True  False   True  False  False   True
# 5  False   True   True  False  False   True
# 6   True  False   True  False  False   True
# 7   True   True   True  False   True  False
# 8   True   True   True  False  False   True

# %%
df.drop(['nan'], axis=1 , inplace =True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        A      B      C      D      E
# 0   True   True  False  False  False
# 1  False   True  False   True  False
# 2  False   True   True  False  False
# 3   True   True  False   True  False
# 4   True  False   True  False  False
# 5  False   True   True  False  False
# 6   True  False   True  False  False
# 7   True   True   True  False   True
# 8   True   True   True  False  False

# %%
freq_itemsets=apriori(df,min_support=.22,use_colnames=True)
freq_itemsets
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support   itemsets
# 0  0.666667        (A)
# 1  0.777778        (B)
# 2  0.666667        (C)
# 3  0.222222        (D)
# 4  0.444444     (A, B)
# 5  0.444444     (A, C)
# 6  0.444444     (B, C)
# 7  0.222222     (D, B)
# 8  0.222222  (A, B, C)

# %%
rules = association_rules(freq_itemsets, metric ="confidence",min_threshold=.5)
rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   antecedents consequents  antecedent support  consequent support   support  \
# 0         (A)         (B)            0.666667            0.777778  0.444444
# 1         (B)         (A)            0.777778            0.666667  0.444444
# 2         (A)         (C)            0.666667            0.666667  0.444444
# 3         (C)         (A)            0.666667            0.666667  0.444444
# 4         (B)         (C)            0.777778            0.666667  0.444444
# 5         (C)         (B)            0.666667            0.777778  0.444444
# 6         (D)         (B)            0.222222            0.777778  0.222222
# 7      (A, B)         (C)            0.444444            0.666667  0.222222
# 8      (A, C)         (B)            0.444444            0.777778  0.222222
# 9      (B, C)         (A)            0.444444            0.666667  0.222222
#
#    confidence      lift  leverage  conviction  zhangs_metric
# 0    0.666667  0.857143 -0.074074    0.666667      -0.333333
# 1    0.571429  0.857143 -0.074074    0.777778      -0.428571
# 2    0.666667  1.000000  0.000000    1.000000       0.000000
# 3    0.666667  1.000000  0.000000    1.000000       0.000000
# 4    0.571429  0.857143 -0.074074    0.777778      -0.428571
# 5    0.666667  0.857143 -0.074074    0.666667      -0.333333
# 6    1.000000  1.285714  0.049383         inf       0.285714
# 7    0.500000  0.750000 -0.074074    0.666667      -0.375000
# 8    0.500000  0.642857 -0.123457    0.444444      -0.500000
# 9    0.500000  0.750000 -0.074074    0.666667      -0.375000

# %%
assoc_rules = rules[['antecedents','consequents','antecedent support','consequent support','support','confidence','lift']]
assoc_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   antecedents consequents  antecedent support  consequent support   support  \
# 0         (A)         (B)            0.666667            0.777778  0.444444
# 1         (B)         (A)            0.777778            0.666667  0.444444
# 2         (A)         (C)            0.666667            0.666667  0.444444
# 3         (C)         (A)            0.666667            0.666667  0.444444
# 4         (B)         (C)            0.777778            0.666667  0.444444
# 5         (C)         (B)            0.666667            0.777778  0.444444
# 6         (D)         (B)            0.222222            0.777778  0.222222
# 7      (A, B)         (C)            0.444444            0.666667  0.222222
# 8      (A, C)         (B)            0.444444            0.777778  0.222222
# 9      (B, C)         (A)            0.444444            0.666667  0.222222
#
#    confidence      lift
# 0    0.666667  0.857143
# 1    0.571429  0.857143
# 2    0.666667  1.000000
# 3    0.666667  1.000000
# 4    0.571429  0.857143
# 5    0.666667  0.857143
# 6    1.000000  1.285714
# 7    0.500000  0.750000
# 8    0.500000  0.642857
# 9    0.500000  0.750000
